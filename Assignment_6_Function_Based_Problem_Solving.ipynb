# %% [markdown]
# <a href="https://colab.research.google.com/github/vasanthiginkala5/Hackathon_Submissions/blob/main/Assignment_6_Function_Based_Problem_Solving.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TASK 6

# %% [markdown]
# 1.Smart Parking Lot Management System

# %%
def smart_parking(capacity, vehicle_logs):
    parked = 0
    peak = 0
    for log in vehicle_logs:
        if log == "IN":
            parked += 1
        elif log == "OUT" and parked > 0:
            parked -= 1
        if parked > peak:
            peak = parked
    print("Currently Parked Vehicles:", parked)
    if parked > capacity:
        print("Parking Status: Over Capacity")
    else:
        print("Parking Status: Available")

    print("Peak Usage:", peak)
smart_parking(50, ["IN", "IN", "IN", "OUT", "IN", "IN", "OUT"])
# Out:
# Currently Parked Vehicles: 3
# Parking Status: Available
# Peak Usage: 4

# %% [markdown]
# 2.Online Food Delivery Time Estimator

# %%
def estimate_delivery_time(distance, traffic, weather):
    eta = distance * 5
    if traffic == "High":
        eta += 15
    elif traffic == "Medium":
        eta += 10
    if weather == "Rainy":
        eta += 10
    elif weather == "Storm":
        eta += 20
    print("Estimated Delivery Time:", eta, "minutes")
estimate_delivery_time(8, "High", "Rainy")
# Out:
# Estimated Delivery Time: 65 minutes

# %% [markdown]
# 3.Movie Theatre Seat Occupancy Analyzer

# %%
def seat_occupancy(total_seats, booked_seats):
    booked = len(booked_seats)
    occupancy = (booked / total_seats) * 100
    print("Occupancy:", round(occupancy, 2), "%")
    if occupancy == 100:
        print("Show Status: Housefull")
    elif occupancy >= 75:
        print("Show Status: Almost Full")
        print("Suggestion: Consider opening additional show")
    else:
        print("Show Status: Seats Available")
seat_occupancy(200, [1]*150)
# Out:
# Occupancy: 75.0 %
# Show Status: Almost Full
# Suggestion: Consider opening additional show

# %% [markdown]
# 4.Cloud Server Load Classification System

# %%
def server_load(cpu_readings):
    avg_cpu = sum(cpu_readings) / len(cpu_readings)
    print("Average CPU Load:", round(avg_cpu, 2), "%")
    if avg_cpu < 50:
        print("Server Status: Normal")
    elif 50 <= avg_cpu <= 80:
        print("Server Status: Warning")
    else:
        print("Server Status: Critical")
server_load([45, 60, 70, 85, 90])
# Out:
# Average CPU Load: 70.0 %
# Server Status: Warning

# %% [markdown]
# 5.Smart Classroom Resource Usage Monitor

# %%
def resource_monitor(resource_usage):
    overused = []
    for resource, hours in resource_usage.items():
        if hours > 8:
            overused.append(resource)
    if overused:
        print("Overused Resources:", ", ".join(overused))
        print("Energy Alert: Yes")
    else:
        print("Overused Resources: None")
        print("Energy Alert: No")
resource_monitor({
    "Projector": 6,
    "AC": 9,
    "Lights": 4
})
# Out:
# Overused Resources: AC
# Energy Alert: Yes

# %% [markdown]
# 6.Online Event Registration Capacity Controller

# %%
def event_registration(capacity, registrations):
    if registrations <= capacity:
        print("Confirmed Registrations:", registrations)
        print("Waitlisted Users: 0")
        print("Registration Status: Open")
    else:
        waitlist = registrations - capacity
        print("Confirmed Registrations:", capacity)
        print("Waitlisted Users:", waitlist)
        print("Registration Status: Closed")
event_registration(100, 105)
# Out:
# Confirmed Registrations: 100
# Waitlisted Users: 5
# Registration Status: Closed
